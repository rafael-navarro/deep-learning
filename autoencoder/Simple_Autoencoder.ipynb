# %% [markdown]
# # A Simple Autoencoder
#
# We'll start off by building a simple autoencoder to compress the MNIST dataset. With autoencoders, we pass input data through an encoder that makes a compressed representation of the input. Then, this representation is passed through a decoder to reconstruct the input data. Generally the encoder and decoder will be built with neural networks, then trained on example data.
#
# ![Autoencoder](assets/autoencoder_1.png)
#
# In this notebook, we'll be build a simple network architecture for the encoder and decoder. Let's get started by importing our libraries and getting the dataset.

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', validation_size=0)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz

# %% [markdown]
# Below I'm plotting an example image from the MNIST dataset. These are 28x28 grayscale images of handwritten digits.

# %%
img = mnist.train.images[2]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %% [markdown]
# We'll train an autoencoder with these images by flattening them into 784 length vectors. The images from this dataset are already normalized such that the values are between 0 and 1. Let's start by building basically the simplest autoencoder with a **single ReLU hidden layer**. This layer will be used as the compressed representation. Then, the encoder is the input layer and the hidden layer. The decoder is the hidden layer and the output layer. Since the images are normalized between 0 and 1, we need to use a **sigmoid activation on the output layer** to get values matching the input.
#
# ![Autoencoder architecture](assets/simple_autoencoder.png)
#
#
# > **Exercise:** Build the graph for the autoencoder in the cell below. The input images will be flattened into 784 length vectors. The targets are the same as the inputs. And there should be one hidden layer with a ReLU activation and an output layer with a sigmoid activation. Feel free to use TensorFlow's higher level API, `tf.layers`. For instance, you would use [`tf.layers.dense(inputs, units, activation=tf.nn.relu)`](https://www.tensorflow.org/api_docs/python/tf/layers/dense) to create a fully connected layer with a ReLU activation. The loss should be calculated with the cross-entropy loss, there is a convenient TensorFlow function for this `tf.nn.sigmoid_cross_entropy_with_logits` ([documentation](https://www.tensorflow.org/api_docs/python/tf/nn/sigmoid_cross_entropy_with_logits)). You should note that `tf.nn.sigmoid_cross_entropy_with_logits` takes the logits, but to get the reconstructed images you'll need to pass the logits through the sigmoid function.

# %%
# Size of the encoding layer (the hidden layer)
encoding_dim = 16 # feel free to change this value

image_size = mnist.train.images.shape[1]

# Input and target placeholders
inputs_ = tf.placeholder(tf.float32, [None, image_size], name='inputs')
targets_ = tf.placeholder(tf.float32, [None, image_size], name='targets')

# Output of hidden layer, single fully connected layer here with ReLU activation
encoded = tf.layers.dense(inputs_, encoding_dim, activation=tf.nn.relu)

# Output layer logits, fully connected layer with no activation
logits = tf.layers.dense(encoded, image_size, activation=None)
# Sigmoid output from logits
decoded = tf.nn.sigmoid(logits, name='output')

# Sigmoid cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=targets_)

# Mean of the loss
cost =  tf.reduce_mean(loss)

# Adam optimizer
opt = tf.train.AdamOptimizer(0.001).minimize(cost)

# %% [markdown]
# ## Training

# %%
# Create the session
sess = tf.Session()

# %% [markdown]
# Here I'll write a bit of code to train the network. I'm not too interested in validation here, so I'll just monitor the training loss.
#
# Calling `mnist.train.next_batch(batch_size)` will return a tuple of `(images, labels)`. We're not concerned with the labels here, we just need the images. Otherwise this is pretty straightfoward training with TensorFlow. We initialize the variables with `sess.run(tf.global_variables_initializer())`. Then, run the optimizer and get the loss with `batch_cost, _ = sess.run([cost, opt], feed_dict=feed)`.

# %%
epochs = 1
batch_size = 200
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        feed = {inputs_: batch[0], targets_: batch[0]}
        batch_cost, _ = sess.run([cost, opt], feed_dict=feed)

        print("\r","Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))
# Out:
#  Epoch: 1/1... Training loss: 0.6948
#  Epoch: 1/1... Training loss: 0.6927
#  Epoch: 1/1... Training loss: 0.6908
#  Epoch: 1/1... Training loss: 0.6889
#  Epoch: 1/1... Training loss: 0.6867
#  Epoch: 1/1... Training loss: 0.6843
#  Epoch: 1/1... Training loss: 0.6817
#  Epoch: 1/1... Training loss: 0.6787
#  Epoch: 1/1... Training loss: 0.6743
#  Epoch: 1/1... Training loss: 0.6695
#  Epoch: 1/1... Training loss: 0.6641
#  Epoch: 1/1... Training loss: 0.6588
#  Epoch: 1/1... Training loss: 0.6509
#  Epoch: 1/1... Training loss: 0.6438
#  Epoch: 1/1... Training loss: 0.6338
#  Epoch: 1/1... Training loss: 0.6247
#  Epoch: 1/1... Training loss: 0.6113
#  Epoch: 1/1... Training loss: 0.6007
#  Epoch: 1/1... Training loss: 0.5899
#  Epoch: 1/1... Training loss: 0.5776
#  Epoch: 1/1... Training loss: 0.5626
#  Epoch: 1/1... Training loss: 0.5499
#  Epoch: 1/1... Training loss: 0.5333
#  Epoch: 1/1... Training loss: 0.5199
#  Epoch: 1/1... Training loss: 0.5037
#  Epoch: 1/1... Training loss: 0.4939
#  Epoch: 1/1... Training loss: 0.4752
#  Epoch: 1/1... Training loss: 0.4622
#  Epoch: 1/1... Training loss: 0.4450
#  Epoch: 1/1... Training loss: 0.4390
#  Epoch: 1/1... Training loss: 0.4241
#  Epoch: 1/1... Training loss: 0.4100
#  Epoch: 1/1... Training loss: 0.4025
#  Epoch: 1/1... Training loss: 0.3904
#  Epoch: 1/1... Training loss: 0.3758
#  Epoch: 1/1... Training loss: 0.3805
#  Epoch: 1/1... Training loss: 0.3648
#  Epoch: 1/1... Training loss: 0.3609
#  Epoch: 1/1... Training loss: 0.3540
#  Epoch: 1/1... Training loss: 0.3413
#  Epoch: 1/1... Training loss: 0.3419
#  Epoch: 1/1... Training loss: 0.3363
#  Epoch: 1/1... Training loss: 0.3292
#  Epoch: 1/1... Training loss: 0.3232
#  Epoch: 1/1... Training loss: 0.3110
#  Epoch: 1/1... Training loss: 0.3141
#  Epoch: 1/1... Training loss: 0.3132
#  Epoch: 1/1... Training loss: 0.3106
#  Epoch: 1/1... Training loss: 0.3096
#  Epoch: 1/1... Training loss: 0.3107
#  Epoch: 1/1... Training loss: 0.3065
#  Epoch: 1/1... Training loss: 0.3037
#  Epoch: 1/1... Training loss: 0.2917
#  Epoch: 1/1... Training loss: 0.2983
#  Epoch: 1/1... Training loss: 0.2951
#  Epoch: 1/1... Training loss: 0.2867
#  Epoch: 1/1... Training loss: 0.2954
#  Epoch: 1/1... Training loss: 0.2886
#  Epoch: 1/1... Training loss: 0.3016
#  Epoch: 1/1... Training loss: 0.2895
#  Epoch: 1/1... Training loss: 0.2839
#  Epoch: 1/1... Training loss: 0.2906
#  Epoch: 1/1... Training loss: 0.2858
#  Epoch: 1/1... Training loss: 0.2851
#  Epoch: 1/1... Training loss: 0.2852
#  Epoch: 1/1... Training loss: 0.2825
#  Epoch: 1/1... Training loss: 0.2850
#  Epoch: 1/1... Training loss: 0.2829
#  Epoch: 1/1... Training loss: 0.2868
#  Epoch: 1/1... Training loss: 0.2900
#  Epoch: 1/1... Training loss: 0.2861
#  Epoch: 1/1... Training loss: 0.2843
#  Epoch: 1/1... Training loss: 0.2871
#  Epoch: 1/1... Training loss: 0.2791
#  Epoch: 1/1... Training loss: 0.2849
#  Epoch: 1/1... Training loss: 0.2733
#  Epoch: 1/1... Training loss: 0.2884
#  Epoch: 1/1... Training loss: 0.2881
#  Epoch: 1/1... Training loss: 0.2836
#  Epoch: 1/1... Training loss: 0.2786
#  Epoch: 1/1... Training loss: 0.2740
#  Epoch: 1/1... Training loss: 0.2785
#  Epoch: 1/1... Training loss: 0.2854
#  Epoch: 1/1... Training loss: 0.2735
#  Epoch: 1/1... Training loss: 0.2817
#  Epoch: 1/1... Training loss: 0.2816
#  Epoch: 1/1... Training loss: 0.2758
#  Epoch: 1/1... Training loss: 0.2774
#  Epoch: 1/1... Training loss: 0.2745
#  Epoch: 1/1... Training loss: 0.2867
#  Epoch: 1/1... Training loss: 0.2732
#  Epoch: 1/1... Training loss: 0.2780
#  Epoch: 1/1... Training loss: 0.2739
#  Epoch: 1/1... Training loss: 0.2717
#  Epoch: 1/1... Training loss: 0.2874
#  Epoch: 1/1... Training loss: 0.2763
#  Epoch: 1/1... Training loss: 0.2765
#  Epoch: 1/1... Training loss: 0.2808
#  Epoch: 1/1... Training loss: 0.2748
#  Epoch: 1/1... Training loss: 0.2749
#  Epoch: 1/1... Training loss: 0.2703
#  Epoch: 1/1... Training loss: 0.2794
#  Epoch: 1/1... Training loss: 0.2743
#  Epoch: 1/1... Training loss: 0.2658
#  Epoch: 1/1... Training loss: 0.2784
#  Epoch: 1/1... Training loss: 0.2773
#  Epoch: 1/1... Training loss: 0.2709
#  Epoch: 1/1... Training loss: 0.2783
#  Epoch: 1/1... Training loss: 0.2660
#  Epoch: 1/1... Training loss: 0.2694
#  Epoch: 1/1... Training loss: 0.2713
#  Epoch: 1/1... Training loss: 0.2709
#  Epoch: 1/1... Training loss: 0.2661
#  Epoch: 1/1... Training loss: 0.2661
#  Epoch: 1/1... Training loss: 0.2657
#  Epoch: 1/1... Training loss: 0.2707
#  Epoch: 1/1... Training loss: 0.2682
#  Epoch: 1/1... Training loss: 0.2706
#  Epoch: 1/1... Training loss: 0.2684
#  Epoch: 1/1... Training loss: 0.2676
#  Epoch: 1/1... Training loss: 0.2633
#  Epoch: 1/1... Training loss: 0.2656
#  Epoch: 1/1... Training loss: 0.2677
#  Epoch: 1/1... Training loss: 0.2676
#  Epoch: 1/1... Training loss: 0.2643
#  Epoch: 1/1... Training loss: 0.2711
#  Epoch: 1/1... Training loss: 0.2688
#  Epoch: 1/1... Training loss: 0.2705
#  Epoch: 1/1... Training loss: 0.2637
#  Epoch: 1/1... Training loss: 0.2635
#  Epoch: 1/1... Training loss: 0.2700
#  Epoch: 1/1... Training loss: 0.2647
#  Epoch: 1/1... Training loss: 0.2674
#  Epoch: 1/1... Training loss: 0.2666
#  Epoch: 1/1... Training loss: 0.2602
#  Epoch: 1/1... Training loss: 0.2667
#  Epoch: 1/1... Training loss: 0.2575
#  Epoch: 1/1... Training loss: 0.2608
#  Epoch: 1/1... Training loss: 0.2610
#  Epoch: 1/1... Training loss: 0.2670
#  Epoch: 1/1... Training loss: 0.2587
#  Epoch: 1/1... Training loss: 0.2598
#  Epoch: 1/1... Training loss: 0.2565
#  Epoch: 1/1... Training loss: 0.2596
#  Epoch: 1/1... Training loss: 0.2653
#  Epoch: 1/1... Training loss: 0.2621
#  Epoch: 1/1... Training loss: 0.2642
#  Epoch: 1/1... Training loss: 0.2644
#  Epoch: 1/1... Training loss: 0.2609
#  Epoch: 1/1... Training loss: 0.2563
#  Epoch: 1/1... Training loss: 0.2585
#  Epoch: 1/1... Training loss: 0.2552
#  Epoch: 1/1... Training loss: 0.2557
#  Epoch: 1/1... Training loss: 0.2639
#  Epoch: 1/1... Training loss: 0.2603
#  Epoch: 1/1... Training loss: 0.2591
#  Epoch: 1/1... Training loss: 0.2608
#  Epoch: 1/1... Training loss: 0.2550
#  Epoch: 1/1... Training loss: 0.2522
#  Epoch: 1/1... Training loss: 0.2547
#  Epoch: 1/1... Training loss: 0.2502
#  Epoch: 1/1... Training loss: 0.2612
#  Epoch: 1/1... Training loss: 0.2529
#  Epoch: 1/1... Training loss: 0.2554
#  Epoch: 1/1... Training loss: 0.2531
#  Epoch: 1/1... Training loss: 0.2598
#  Epoch: 1/1... Training loss: 0.2530
#  Epoch: 1/1... Training loss: 0.2521
#  Epoch: 1/1... Training loss: 0.2428
#  Epoch: 1/1... Training loss: 0.2497
#  Epoch: 1/1... Training loss: 0.2495
#  Epoch: 1/1... Training loss: 0.2478
#  Epoch: 1/1... Training loss: 0.2506
#  Epoch: 1/1... Training loss: 0.2492
#  Epoch: 1/1... Training loss: 0.2482
#  Epoch: 1/1... Training loss: 0.2522
#  Epoch: 1/1... Training loss: 0.2503
#  Epoch: 1/1... Training loss: 0.2526
#  Epoch: 1/1... Training loss: 0.2428
#  Epoch: 1/1... Training loss: 0.2519
#  Epoch: 1/1... Training loss: 0.2373
#  Epoch: 1/1... Training loss: 0.2487
#  Epoch: 1/1... Training loss: 0.2463
#  Epoch: 1/1... Training loss: 0.2466
#  Epoch: 1/1... Training loss: 0.2427
#  Epoch: 1/1... Training loss: 0.2461
#  Epoch: 1/1... Training loss: 0.2521
#  Epoch: 1/1... Training loss: 0.2441
#  Epoch: 1/1... Training loss: 0.2411
#  Epoch: 1/1... Training loss: 0.2439
#  Epoch: 1/1... Training loss: 0.2488
#  Epoch: 1/1... Training loss: 0.2452
#  Epoch: 1/1... Training loss: 0.2426
#  Epoch: 1/1... Training loss: 0.2461
#  Epoch: 1/1... Training loss: 0.2461
#  Epoch: 1/1... Training loss: 0.2431
#  Epoch: 1/1... Training loss: 0.2357
#  Epoch: 1/1... Training loss: 0.2394
#  Epoch: 1/1... Training loss: 0.2356
#  Epoch: 1/1... Training loss: 0.2403
#  Epoch: 1/1... Training loss: 0.2413
#  Epoch: 1/1... Training loss: 0.2383
#  Epoch: 1/1... Training loss: 0.2409
#  Epoch: 1/1... Training loss: 0.2314
#  Epoch: 1/1... Training loss: 0.2396
#  Epoch: 1/1... Training loss: 0.2346
#  Epoch: 1/1... Training loss: 0.2420
#  Epoch: 1/1... Training loss: 0.2398
#  Epoch: 1/1... Training loss: 0.2388
#  Epoch: 1/1... Training loss: 0.2344
#  Epoch: 1/1... Training loss: 0.2404
#  Epoch: 1/1... Training loss: 0.2407
#  Epoch: 1/1... Training loss: 0.2370
#  Epoch: 1/1... Training loss: 0.2399
#  Epoch: 1/1... Training loss: 0.2356
#  Epoch: 1/1... Training loss: 0.2350
#  Epoch: 1/1... Training loss: 0.2379
#  Epoch: 1/1... Training loss: 0.2400
#  Epoch: 1/1... Training loss: 0.2352
#  Epoch: 1/1... Training loss: 0.2323
#  Epoch: 1/1... Training loss: 0.2323
#  Epoch: 1/1... Training loss: 0.2331
#  Epoch: 1/1... Training loss: 0.2331
#  Epoch: 1/1... Training loss: 0.2246
#  Epoch: 1/1... Training loss: 0.2357
#  Epoch: 1/1... Training loss: 0.2284
#  Epoch: 1/1... Training loss: 0.2265
#  Epoch: 1/1... Training loss: 0.2338
#  Epoch: 1/1... Training loss: 0.2342
#  Epoch: 1/1... Training loss: 0.2278
#  Epoch: 1/1... Training loss: 0.2249
#  Epoch: 1/1... Training loss: 0.2372
#  Epoch: 1/1... Training loss: 0.2303
#  Epoch: 1/1... Training loss: 0.2264
#  Epoch: 1/1... Training loss: 0.2312
#  Epoch: 1/1... Training loss: 0.2277
#  Epoch: 1/1... Training loss: 0.2226
#  Epoch: 1/1... Training loss: 0.2231
#  Epoch: 1/1... Training loss: 0.2270
#  Epoch: 1/1... Training loss: 0.2320
#  Epoch: 1/1... Training loss: 0.2288
#  Epoch: 1/1... Training loss: 0.2252
#  Epoch: 1/1... Training loss: 0.2256
#  Epoch: 1/1... Training loss: 0.2290
#  Epoch: 1/1... Training loss: 0.2268
#  Epoch: 1/1... Training loss: 0.2287
#  Epoch: 1/1... Training loss: 0.2198
#  Epoch: 1/1... Training loss: 0.2259
#  Epoch: 1/1... Training loss: 0.2217
#  Epoch: 1/1... Training loss: 0.2239
#  Epoch: 1/1... Training loss: 0.2245
#  Epoch: 1/1... Training loss: 0.2324
#  Epoch: 1/1... Training loss: 0.2241
#  Epoch: 1/1... Training loss: 0.2172
#  Epoch: 1/1... Training loss: 0.2241
#  Epoch: 1/1... Training loss: 0.2205
#  Epoch: 1/1... Training loss: 0.2224
#  Epoch: 1/1... Training loss: 0.2272
#  Epoch: 1/1... Training loss: 0.2270
#  Epoch: 1/1... Training loss: 0.2254
#  Epoch: 1/1... Training loss: 0.2189
#  Epoch: 1/1... Training loss: 0.2182
#  Epoch: 1/1... Training loss: 0.2231
#  Epoch: 1/1... Training loss: 0.2199
#  Epoch: 1/1... Training loss: 0.2242
#  Epoch: 1/1... Training loss: 0.2207
#  Epoch: 1/1... Training loss: 0.2205
#  Epoch: 1/1... Training loss: 0.2181
#  Epoch: 1/1... Training loss: 0.2242
#  Epoch: 1/1... Training loss: 0.2218
#  Epoch: 1/1... Training loss: 0.2222
#  Epoch: 1/1... Training loss: 0.2167
#  Epoch: 1/1... Training loss: 0.2190
#  Epoch: 1/1... Training loss: 0.2112
#  Epoch: 1/1... Training loss: 0.2196
#  Epoch: 1/1... Training loss: 0.2181
#  Epoch: 1/1... Training loss: 0.2184
#  Epoch: 1/1... Training loss: 0.2234
#  Epoch: 1/1... Training loss: 0.2154
#  Epoch: 1/1... Training loss: 0.2172
#  Epoch: 1/1... Training loss: 0.2189
#  Epoch: 1/1... Training loss: 0.2195
#  Epoch: 1/1... Training loss: 0.2156
#  Epoch: 1/1... Training loss: 0.2174
#  Epoch: 1/1... Training loss: 0.2166
#  Epoch: 1/1... Training loss: 0.2140
#  Epoch: 1/1... Training loss: 0.2147
#  Epoch: 1/1... Training loss: 0.2168
#  Epoch: 1/1... Training loss: 0.2182
#  Epoch: 1/1... Training loss: 0.2128
#  Epoch: 1/1... Training loss: 0.2183
#  Epoch: 1/1... Training loss: 0.2121
#  Epoch: 1/1... Training loss: 0.2147
#  Epoch: 1/1... Training loss: 0.2114
#  Epoch: 1/1... Training loss: 0.2163
#  Epoch: 1/1... Training loss: 0.2096
#  Epoch: 1/1... Training loss: 0.2134
#  Epoch: 1/1... Training loss: 0.2154
#  Epoch: 1/1... Training loss: 0.2145
#  Epoch: 1/1... Training loss: 0.2098

# %% [markdown]
# ## Checking out the results
#
# Below I've plotted some of the test images along with their reconstructions. For the most part these look pretty good except for some blurriness in some parts.

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
reconstructed, compressed = sess.run([decoded, encoded], feed_dict={inputs_: in_imgs})

for images, row in zip([in_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

fig.tight_layout(pad=0.1)

# %%
sess.close()

# %% [markdown]
# ## Up Next
#
# We're dealing with images here, so we can (usually) get better performance using convolution layers. So, next we'll build a better autoencoder with convolutional layers.
#
# In practice, autoencoders aren't actually better at compression compared to typical methods like JPEGs and MP3s. But, they are being used for noise reduction, which you'll also build.
